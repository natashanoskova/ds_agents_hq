# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#ОПИСАНИЕ-ПРОЕКТА" data-toc-modified-id="ОПИСАНИЕ-ПРОЕКТА-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>ОПИСАНИЕ ПРОЕКТА</strong></a></span><ul class="toc-item"><li><span><a href="#План-работы" data-toc-modified-id="План-работы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>План работы</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Наименование-признаков" data-toc-modified-id="Наименование-признаков-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Наименование признаков</a></span></li><li><span><a href="#Расчёт-эффективности" data-toc-modified-id="Расчёт-эффективности-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Расчёт эффективности</a></span></li><li><span><a href="#Метрика-качества" data-toc-modified-id="Метрика-качества-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Метрика качества</a></span></li></ul></li><li><span><a href="#ПОДГОТОВКА-ДАННЫХ" data-toc-modified-id="ПОДГОТОВКА-ДАННЫХ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><strong>ПОДГОТОВКА ДАННЫХ</strong></a></span><ul class="toc-item"><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучение данных</a></span></li><li><span><a href="#Проверка-корректности-расчета-эффективности-обогащения" data-toc-modified-id="Проверка-корректности-расчета-эффективности-обогащения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка корректности расчета эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#АНАЛАЗ-ДАННЫХ" data-toc-modified-id="АНАЛАЗ-ДАННЫХ-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><strong>АНАЛАЗ ДАННЫХ</strong></a></span><ul class="toc-item"><li><span><a href="#Анализ-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Анализ-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Сравнение-распределений-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Сравнение-распределений-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сравнение распределений размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах" data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах</a></span></li></ul></li><li><span><a href="#МОДЕЛЬ" data-toc-modified-id="МОДЕЛЬ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><strong>МОДЕЛЬ</strong></a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучение-моделей-и-оценка-их-качества-кросс-валидацией" data-toc-modified-id="Обучение-моделей-и-оценка-их-качества-кросс-валидацией-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучение моделей и оценка их качества кросс-валидацией</a></span></li></ul></li><li><span><a href="#РЕЗУЛЬТАТЫ" data-toc-modified-id="РЕЗУЛЬТАТЫ-5"><span class="toc-item-num">5&nbsp;&nbsp;</span><strong>РЕЗУЛЬТАТЫ</strong></a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# ## **ОПИСАНИЕ ПРОЕКТА**

# %% [markdown]
# Задача: подготовить прототип модели машинного обучения для компании «Цифры», которая разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Необходимо использовать данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Нам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# Данные находятся в трёх файлах:
#
#
#     gold_recovery_train_new.csv — обучающая выборка;
#     gold_recovery_test_new.csv — тестовая выборка;
#     gold_recovery_full_new.csv — исходные данные.
#
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
#
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
#
# В нашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, необходимо проверить их на корректность.

# %% [markdown]
# ### План работы

# %% [markdown]
# 1. Подготовка данных
#
#
# 1.1. Открыть файлы и изучить их.
#
# 1.2. Проверить, что эффективность обогащения рассчитана правильно. Вычислить её на обучающей выборке для признака rougher.output.recovery. Найти **MAE** между расчётами и значением признака. Выводы.
#
#
# 1.3. Проанализировать признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
#
#
# 1.4. Предобработка данных.

# %% [markdown]
# 2. Анализ данных
#
#
# 2.1. Исследовать, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Описать выводы.
#
#
# 2.2.  Сравнить распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#
#
# 2.3. Исследовать суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %% [markdown]
# 3. Построение модели
#
#
# 3.1. Написать функцию для вычисления итоговой **sMAPE**.
#
#
# 3.2. Обучить разные модели и оценить их качество кросс-валидацией. Выбрать лучшую модель и проверить её на тестовой выборке. Выводы.

# %% [markdown]
# ### Описание данных
#
#
# **Технологический процесс**:
#
#
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
#
# **1. Флотация**
#
#
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
#
# **2. Очистка**
#
#
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
#
# **Обозначения и термины**:
#
#
#
# *Rougher feed* — исходное сырье
#
#
# *Rougher additions* (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant:
#
#     Xanthate** — ксантогенат (промотер, или активатор флотации);
#     Sulphate — сульфат (на данном производстве сульфид натрия);
#     Depressant — депрессант (силикат натрия).
#
#
# *Rougher process* (англ. «грубый процесс») — флотация
#
#
# *Rougher tails* — отвальные хвосты
#
#
# *Float banks* — флотационная установка
#
#
# *Cleaner process* — очистка
#
#
# *Rougher Au* — черновой концентрат золота
#
#
# *Final Au* — финальный концентрат золота

# %% [markdown]
# **Параметры этапов**:
#
#
# *air amount* — объём воздуха
#
#
# *fluid levels* — уровень жидкости
#
#
# *feed size* — размер гранул сырья
#
#
# *feed rate* — скорость подачи

# %% [markdown]
# ### Наименование признаков
#
#
# Наименование признаков должно быть такое:
#
#
# **[этап].[тип_параметра].[название_параметра]**
#
#
# *Пример*: **rougher.input.feed_ag**
#
#
# - Возможные значения для блока **[этап]**:
#
#
# *rougher* — флотация
#
#
# *primary_cleaner* — первичная очистка
#
#
# *secondary_cleaner* — вторичная очистка
#
#
# *final* — финальные характеристики
#
#
# - Возможные значения для блока **[тип_параметра]**:
#
#
# *input* — параметры сырья
#
#
# *output* — параметры продукта
#
#
# *state* — параметры, характеризующие текущее состояние этапа
#
#
# *calculation* — расчётные характеристики

# %% [markdown]
# ### Расчёт эффективности
#
# Нам нужно смоделировать процесс восстановления золота из золотосодержащей руды.
#
#
# **Эффективность обогащения рассчитывается по формуле**:

# %% [markdown]
# $$Recovery\; =\; \frac{C \times (F - T)}{F \times (C - T)}\; \times 100\%$$

# %% [markdown]
# где:
#
#         C — доля золота в концентрате после флотации/очистки;
#         F — доля золота в сырье/концентрате до флотации/очистки;
#         T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# ### Метрика качества
#
#
# Для решения задачи введём новую метрику качества — **sMAPE** (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
#
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
#
# Метрика **sMAPE** вычисляется так:

# %% [markdown]
# $$sMAPE\; =\; \frac{1}{N}\sum_{i=1}^{N}\; \frac{2\; |y_i - \widehat{y_i}|}{ |y_i| + |\widehat{y_i}|}\; \times 100\%$$

# %% [markdown]
# $y_i$ - значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество,
#
#
# $\widehat{y_i}$ - значение предсказания для объекта с порядковым номером i, например, в тестовой выборке,
#
#
# $N$ - количество объектов в выборке,
#
#
# $\sum_{i=1}^{N}$ - суммирование по всем объектам выборки (i меняется от 1 до N).

# %% [markdown]
# **Нужно спрогнозировать сразу две величины**:
#
#
# эффективность обогащения чернового концентрата **rougher.output.recovery**;
#
#
# эффективность обогащения финального концентрата **final.output.recovery**.
#
#
# **Итоговая метрика** складывается из двух величин:

# %% [markdown]
# $$ИТОГОВОЕ\;\; \normalsize sMAPE\; =\; 25\% \; \times sMAPE(rougher)\;\; +\;\; 75\% \;\times sMAPE(final)$$

# %%
# !pip install "kaleido==0.2.1"

# %%
import pandas as pd
import numpy as np

from numpy.random import RandomState

from sklearn.impute import KNNImputer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor

from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_absolute_percentage_error

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.io as pio

import warnings
warnings.simplefilter(action='ignore')

# %%
STATE = np.random.RandomState(0)

# %%
pio.renderers.default = "jpeg"
current_template = pio.templates.default or "plotly"
pio.templates[current_template].layout = dict(width = 1100, height = 550)

# %% [markdown]
# ## **ПОДГОТОВКА ДАННЫХ**

# %% [markdown]
# ### Изучение данных

# %%
try:
    train = pd.read_csv('C:\\Users\\1\\Downloads\\gold_recovery_train_new.csv')
    test = pd.read_csv('C:\\Users\\1\\Downloads\\gold_recovery_test_new.csv')
    full = pd.read_csv('C:\\Users\\1\\Downloads\\gold_recovery_full_new.csv')
except:  
    train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
    test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
    full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
datasets = [train, test, full]

train.name = 'ОБУЧАЮЩАЯ ВЫБОРКА'
test.name = 'ТЕСТОВАЯ ВЫБОРКА'
full.name = 'ИСХОДНЫЕ ДАННЫЕ'

# %%
def report(dataset):
    print()
    print('ОТЧЕТ О ДАТАСЕТЕ', dataset.name)
    print()
    print(f'Размер датасета: {dataset.shape[0]} строк, {dataset.shape[1]} колонок')
    print(f'Датасет составляет {len(dataset) / len(full):.1%} исходного набора данных')
    print('Количество пропусков :', dataset.isna().sum().sum())
    print('Количество полных дубликатов', dataset.duplicated().sum())
    print()
    print('Образец данных')
    display(dataset.head())
    print()
    print('Общая информация, типы данных, пропуски')
    print()
    dataset.info()
    print()
    print('Доля пропусков в колонках')
    print()
    print(dataset.isna().mean())
    print()
    print('Статистическая общая информация')
    display(dataset.describe())
    print()
    print()

# %%
for dataset in datasets:
    report(dataset)
# Out:
# ОТЧЕТ О ДАТАСЕТЕ ОБУЧАЮЩАЯ ВЫБОРКА
#
# Размер датасета: 14149 строк, 87 колонок
# Датасет составляет 72.8% исходного набора данных
# Количество пропусков : 4100
# Количество полных дубликатов 0
#
# Образец данных
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
# ...

# %% [markdown]
# **В данных**:
#
#     есть пропуски,
#     данные имеют большой разброс, отрицательные значения, например, в столбцах secondary_cleaner.state.floatbank#,
#     дата и время получения информации (признак date) имеет тип данных object,
#     данные индексируются датой и временем получения информации (признак date) с шагом в 1 час,
#     остальные признаки, характеризующие технологический процесс имеют тип данных float64,
#     соседние по времени параметры часто похожи - по условиям задачи,
#     полных дубликатов нет,
#     обучающая выборка составляет ~ 73% исходных данных,
#     тестовая выборка ~ 27% исходных данных,
#     тестовая выборка содержит меньшее количество признаков, чем обучающая,
#     исходный датасет имеет 19439 наблюдений, 87 признаков.

# %% [markdown]
# ### Проверка корректности расчета эффективности обогащения
#
# - Вычислить её на **обучающей выборке** для признака **rougher.output.recovery**.
#
# - Найти **MAE между нашими расчётами и значением признака**. Сделать выводы.

# %% [markdown]
# $$Recovery\; =\; \frac{C \times (F - T)}{F \times (C - T)}\; \times 100\%$$

# %% [markdown]
# где:
#
#         C — доля золота в концентрате после флотации/очистки;
#         F — доля золота в сырье/концентрате до флотации/очистки;
#         T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %%
C = train['rougher.output.concentrate_au']
F = train['rougher.input.feed_au']
T = train['rougher.output.tail_au']

# %%
Recovery = (C * (F - T)) / (F * (C - T)) * 100

print('MAE между расчётами и значением признака :', mae(Recovery, train['rougher.output.recovery']))
# Out:
# MAE между расчётами и значением признака : 9.73512347450521e-15

# %% [markdown]
# *Эффективность обогащения рассчитана правильно, так как значение ***MAE*** между расчётами и значением признака в данных крайне мало*.

# %% [markdown]
# ### Анализ признаков, недоступных в тестовой выборке
#
# Что это за параметры? К какому типу относятся?

# %% [markdown]
#     Одинаковые колонки в обучающей и тестовой выборках:

# %%
set(test.columns) & set(train.columns)
# Out:
# {'date',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.xanthate',
#  'primary_cleaner.state.floatbank8_a_air',
#  'primary_cleaner.state.floatbank8_a_level',
#  'primary_cleaner.state.floatbank8_b_air',
#  'primary_cleaner.state.floatbank8_b_level',
#  'primary_cleaner.state.floatbank8_c_air',
#  'primary_cleaner.state.floatbank8_c_level',
#  'primary_cleaner.state.floatbank8_d_air',
#  'primary_cleaner.state.floatbank8_d_level',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_au',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
# ...

# %% [markdown]
#     Колонки, которые отсутствуют в тестовой выборке:

# %%
set(train.columns) - set(test.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
#     Процент совпадающих и отсутствующих колонок:

# %%
pd.Series(train.columns).isin(pd.Series(test.columns)).value_counts(normalize=True) * 100
# Out:
# True     60.91954
# False    39.08046
# dtype: float64

# %% [markdown]
# *Как можно заметить, в тестовой выборке отсутствует* ***39% параметров*** *обучающей выборки, отсутствуют все выходные параметры* : ***output;***  *и расчеты* : ***calculation***, *а главное* -
#
#
# *целевые признаки* ***rougher.output.recovery и final.output.recovery***, *которые нужны для расчета метрики качества* ***sMAPE***.

# %% [markdown]
#     Согласно описанию проекта:
#
#     Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже (онлайн метрики).
#
#     Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
#     Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
#     Добавим в тестовую выборку из исходного набора данных целевые признаки по индексу date. Удалим этот признак из тестовой и обучающей выборок, т.к. они не понадобятся для обучения моделей и будут мешать при заполнении пропусков.

# %%
test_ml = test.merge(full.loc[:,['date', 
                                 'rougher.output.recovery', 
                                 'final.output.recovery']], 
                                  on = 'date'
                    ).drop(['date'], axis = 1)
    
print('Размер тестовой выборки :', test_ml.shape)
# Out:
# Размер тестовой выборки : (5290, 54)

# %%
train_ml = train.drop(['date'], axis = 1)

print('Размер обучающей выборки :', train_ml.shape)
# Out:
# Размер обучающей выборки : (14149, 86)

# %%
def impute_missing_values(dataset):
    
    imputer = KNNImputer(n_neighbors=2)

    dataset = pd.DataFrame(imputer.fit_transform(dataset),
                           columns = dataset.columns,
                           index = dataset.index)
    
    
    print('Количество пропусков :', dataset.isna().sum().sum())
    print('Размер выборки       :', dataset.shape)
    
    return dataset

# %%
train_ml = impute_missing_values(train_ml)
# Out:
# Количество пропусков : 0
# Размер выборки       : (14149, 86)

# %%
test_ml = impute_missing_values(test_ml)
# Out:
# Количество пропусков : 0
# Размер выборки       : (5290, 54)

# %% [markdown]
# ## **АНАЛАЗ ДАННЫХ**

# %% [markdown]
# ### Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
def metal_stages(metal, color):
    
    data = full[['rougher.input.feed_'+ metal, 
                 'rougher.output.concentrate_'+ metal,
                 'primary_cleaner.output.concentrate_'+ metal,
                 'final.output.concentrate_'+ metal]]
        
    fig = px.violin(data, 
                    x=data.columns,
                    box=True,
                    violinmode='overlay'
                   )
    fig.update_traces(marker_color=color, meanline_visible=True) 
    
    fig.update_layout(title=f'ИЗМЕНЕНИЕ КОНЦЕНТРАЦИИ МЕТАЛЛА <b>"{str(metal).upper()}"</b> НА РАЗЛИЧНЫХ СТАДИЯХ ОЧИСТКИ', 
                      title_x=0.5, 
                      margin=dict(t=50, l=0, r=0, b=0),
                      violingroupgap=0)
    
    fig.show()
    
    
    fig = go.Figure(data=[go.Table(columnwidth = [20, 60, 80, 100, 70],
                                   header=dict(values=data.describe().round(2).reset_index().columns,
                                               font=dict(color='white', size=14),
                                               line_color='darkslategray',
                                               fill_color=color,
                                               align='left'),
                                   cells=dict(values=data.describe().round(2).reset_index().values.T, 
                                              line_color='darkslategray',
                                              align='left'))
                          ])
    fig.update_layout(title=f'Статистические данные', 
                      title_x=0.5, 
                      margin=dict(t=50, l=0, r=0, b=0),
                      height=300)
    
    fig.show()

# %%
metals = ['au', 'ag', 'pb']
colors = ['orange', 'grey', 'darkslategrey']

# %%
for metal, color in zip(metals, colors):
    metal_stages(metal, color)

# %% [markdown]
#     ЗОЛОТО:
#     Концентрация золота увеличивается, проходя все стадии очистки. Финальная концентрация примерно в 5,6 раза больше концентрации в сырье.
#
#     СЕРЕБРО:
#     Концентрация серебра достигает максимального среднего/медианного значения на этапе флотации, и далее начинает снижаться до уровня, ниже концентрации в первичном сырье.
#
#     СВИНЕЦ:
#     Концентрация свинца растет до уровня после первичной очистки, и далее увеличивается незначительно.

# %% [markdown]
# Сравним концентрации металлов на каждой стадии процесса очистки.

# %%
def stage_metals(stage):
    
    data = full[[stage + '_au', 
                 stage + '_ag',
                 stage + '_pb']]
        
    fig = px.violin(data, 
                    x=data.columns,
                    box=True,  
                    color='variable',
                    color_discrete_sequence= ['orange', 'grey', 'darkslategrey'], 
                    violinmode='overlay'
                   ) 
    fig.update_traces(meanline_visible=True)  
    
    fig.update_layout(title=f'СРАВНЕНИЕ КОНЦЕНТРАЦИИ ВСЕХ МЕТАЛЛОВ AU, AG, PB НА СТАДИИ ОЧИСТКИ <b>"{str(stage).upper()}"</b>', 
                      title_x=0.5, title_font_size=13, 
                      margin=dict(t=50, l=0, r=0, b=0),
                      violingroupgap=0)
    
    fig.show()

# %%
stages = ['rougher.input.feed', 
          'rougher.output.concentrate', 
          'primary_cleaner.output.concentrate', 
          'final.output.concentrate']

# %%
for stage in stages:
    stage_metals(stage)

# %% [markdown]
# ### Сравнение распределений размеров гранул сырья на обучающей и тестовой выборках
#
#     Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
train_feature = train_ml['rougher.input.feed_size']
test_feature = test_ml['rougher.input.feed_size']

# %%
group_labels = ['train_feature', 'test_feature']
colors = ['limegreen', 'magenta']

fig = ff.create_distplot([train_feature, test_feature],
                          group_labels, show_hist=False,
                          show_rug=False, colors=colors
                         )
fig.update_layout(title_text='Распределение размеров гранул сырья на обучающей и тестовой выборках',
                  title_x=0.5, margin=dict(t=50, l=0, r=0, b=0), 
                  xaxis_title='rougher.input.feed_size')
fig.show()

# %%
pd.DataFrame({' ': ['min', 'mean', 'median', 'max'],
              
              test.name  : [test_feature.min(), test_feature.mean(), 
                            test_feature.median(), test_feature.max()],
              
              train.name : [train_feature.min(), train_feature.mean(), 
                            train_feature.median(), train_feature.max()]})
# Out:
#            ТЕСТОВАЯ ВЫБОРКА  ОБУЧАЮЩАЯ ВЫБОРКА
# 0     min          0.046369           9.659576
# 1    mean         55.953700          60.142646
# 2  median         50.846843          55.377622
# 3     max        392.494040         484.967466

# %% [markdown]
#     Статистические параметры распределений размеров гранул сырья на обучающей и тестовой выборках различаются незначительно.

# %% [markdown]
# ### Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %%
train_sum_rougher_input = (train_ml['rougher.input.feed_au'] + 
                           train_ml['rougher.input.feed_ag'] + 
                           train_ml['rougher.input.feed_pb'] +
                           train_ml['rougher.input.feed_sol'])

train_sum_rougher_output = (train_ml['rougher.output.concentrate_au'] + 
                            train_ml['rougher.output.concentrate_ag'] + 
                            train_ml['rougher.output.concentrate_pb'] +
                            train_ml['rougher.output.concentrate_sol'])

train_sum_final_output = (train_ml['final.output.concentrate_au'] + 
                          train_ml['final.output.concentrate_ag'] + 
                          train_ml['final.output.concentrate_pb'] +
                          train_ml['final.output.concentrate_sol'])

# %%
pd.DataFrame({' ': ['min', 'mean', 'median', 'max'],
              
              'СЫРЬЕ'  : [train_sum_rougher_input.min(), train_sum_rougher_input.mean(), 
                          train_sum_rougher_input.median(), train_sum_rougher_input.max()],
              
              'ЧЕРНОВОЙ КОНЦЕНТРАТ' : [train_sum_rougher_output.min(), train_sum_rougher_output.mean(), 
                                       train_sum_rougher_output.median(), train_sum_rougher_output.max()],
              
              'ФИНАЛЬНЫЙ КОНЦЕНТРАТ' : [train_sum_final_output.min(), train_sum_final_output.mean(), 
                                        train_sum_final_output.median(), train_sum_final_output.max()]           
                           
             })
# Out:
#                СЫРЬЕ  ЧЕРНОВОЙ КОНЦЕНТРАТ  ФИНАЛЬНЫЙ КОНЦЕНТРАТ
# 0     min   0.040000             0.000000              0.000000
# 1    mean  56.263527            67.184341             68.445463
# 2  median  56.627137            69.175954             69.149759
# 3     max  74.458253            88.140119             80.210644

# %%
group_labels = ['sum rougher input', 'sum rougher output', 'sum final output']
colors = ['green', 'steelblue', 'deeppink']

fig = ff.create_distplot([train_sum_rougher_input, 
                          train_sum_rougher_output, 
                          train_sum_final_output],
                          group_labels, show_rug=False,
                          colors=colors
                         )
fig.update_layout(title_text='Cуммарная концентрация всех веществ в сырье, в черновом и финальном концентратах',
                  title_x=0.5, margin=dict(t=50, l=0, r=0, b=0), 
                  bargap=0.2,   
                  xaxis_title='суммарная концентрация'
                  )
fig.show()

# %% [markdown]
#     Средняя/медианная суммарная концентрация всех веществ в сырье примерно на 19% меньше, чем на этапе чернового и финального концентрата.

# %% [markdown]
#     В данных присутствуют нулевые и около нулевые значения концентраций, что скорее всего является ошибкой, вероятно связанной со сбоем измерительного оборудования. Такие наблюдения следует удалить из обучающих данных.

# %%
features_list = ['rougher.input.feed_au', 
                 'rougher.input.feed_ag', 
                 'rougher.input.feed_pb', 
                 'rougher.input.feed_sol',
                 'rougher.output.concentrate_au', 
                 'rougher.output.concentrate_ag',
                 'rougher.output.concentrate_pb',
                 'rougher.output.concentrate_sol',
                 'final.output.concentrate_au',
                 'final.output.concentrate_ag',
                 'final.output.concentrate_pb',
                 'final.output.concentrate_sol']

# %%
def drop_outliers(data, feature):
    
    data = data[~(data[feature] < 1)]
    
    return data

# %%
for feature in features_list:
    train_ml = drop_outliers(train_ml, feature)

    
print('Размер выборки              :', train_ml.shape)
print('Удаленные выбросы составили :', '{:.1%}'.format(1 - train_ml.shape[0] / train.shape[0]))
# Out:
# Размер выборки              : (13643, 86)
# Удаленные выбросы составили : 3.6%

# %% [markdown]
# ## **МОДЕЛЬ**

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE

# %% [markdown]
# $$sMAPE\; =\; \frac{1}{N}\sum_{i=1}^{N}\; \frac{2\; |y_i - \widehat{y_i}|}{ |y_i| + |\widehat{y_i}|}\; \times 100\%$$

# %% [markdown]
# $y_i$ - значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество,
#
#
# $\widehat{y_i}$ - значение предсказания для объекта с порядковым номером i, например, в тестовой выборке,
#
#
# $N$ - количество объектов в выборке,
#
#
# $\sum_{i=1}^{N}$ - суммирование по всем объектам выборки (i меняется от 1 до N).

# %% [markdown]
# $$ИТОГОВОЕ\;\; \normalsize sMAPE\; =\; 25\% \; \times sMAPE(rougher)\;\; +\;\; 75\% \;\times sMAPE(final)$$

# %% [markdown]
#     Удалим из обучающей выборки признаки, которых нет в тестовой.

# %%
train_ml = train_ml[test_ml.columns]

print('Размер обучающей выборки :', train_ml.shape)
# Out:
# Размер обучающей выборки : (13643, 54)

# %% [markdown]
#     Выделим в выборках признаки и целевые признаки.

# %%
target_train = train_ml[['rougher.output.recovery', 'final.output.recovery']] 
features_train = train_ml.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

target_test = test_ml[['rougher.output.recovery', 'final.output.recovery']] 
features_test = test_ml.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

# %%
train_ml['rougher.output.recovery']
# Out:
# 0        87.107763
# 1        86.843261
# 2        86.842308
# 3        87.226430
# 4        86.688794
#            ...
# 14144    89.574376
# 14145    87.724007
# 14146    88.890579
# 14147    89.858126
# 14148    89.514960
# Name: rougher.output.recovery, Length: 13643, dtype: float64

# %%
train_ml['final.output.recovery']
# Out:
# 0        70.541216
# 1        69.266198
# 2        68.116445
# 3        68.347543
# 4        66.927016
#            ...
# 14144    73.755150
# 14145    69.049291
# 14146    67.002189
# 14147    65.523246
# 14148    70.281454
# Name: final.output.recovery, Length: 13643, dtype: float64

# %%
np.array(train_ml['rougher.output.recovery'], train_ml['final.output.recovery'])
# Out:
# array([87.10776293, 86.84326051, 86.84230826, ..., 88.89057853,
#        89.858126  , 89.51495973])

# %%
def smape(target, predicted):
    
    smape_rougher = sum(2 * abs(target[:, 0] - predicted[:, 0]) / 
                       ((abs(target[:, 0]) + abs(predicted[:, 0])))) / len(target) * 100
                        
    smape_final = sum(2 * abs(target[:, 1] - predicted[:, 1]) / 
                     ((abs(target[:, 1]) + abs(predicted[:, 1])))) / len(target) * 100
    
    smape = 0.25 * smape_rougher + 0.75 * smape_final
    
    return smape

# %%
smape_score = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# ### Обучение моделей и оценка их качества кросс-валидацией
#
#     Выбираем лучшую модель, проверяем её на тестовой выборке. Выводы.

# %% [markdown]
#     Рассмотрим алгоритмы Линейной регрессии, Случайный лес и Дерево решений.

# %% [markdown]
# Получим оценку sMAPE дамми-регрессора для того, чтобы найти не худший скоринг для алгоритмов регрессии на обучающей выборке.

# %%
dr = DummyRegressor()

smape_dr = cross_val_score(dr, features_train, 
                           np.array(target_train), 
                           scoring=smape_score, cv=5
                           ).mean() *-1

print('Оценка качества модели дамми регрессора по метрике sMAPE  :', smape_dr)
# Out:
# Оценка качества модели дамми регрессора по метрике sMAPE  : 9.63063570419063

# %% [markdown]
# **Алгоритм Случайного леса**

# %%
# %%time                                                            
best_model_rf = None                                              
best_smape_rf = smape_dr                                          
                                                                 
for est in range(2, 5, 1):                                       
    for depth in range(2, 5, 1):                                 
        rf = RandomForestRegressor(random_state=STATE,           
                                   n_estimators=est,             
                                   max_depth=depth) 
                
        smape_rf = cross_val_score(rf, features_train, 
                                   np.array(target_train), 
                                   scoring=smape_score, cv=5
                                   ).mean() *-1
        
        if smape_rf < best_smape_rf:
            best_smape_rf = smape_rf
            best_model_rf = rf
        
print(best_model_rf)
print(best_smape_rf)
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=2,
#                       random_state=RandomState(MT19937) at 0x26C102B5740)
# 8.631799638535053
# CPU times: total: 1min 15s
# Wall time: 1min 15s

# %% [markdown]
# **Алгритм Дерева решений**

# %%
# %%time
best_model_dtr = None
best_smape_dtr = smape_dr

for features in range(2, 15, 2):
    for depth in range(1, 11, 1):
        dtr = DecisionTreeRegressor(random_state=STATE, 
                                    max_features=features, 
                                    max_depth=depth) 
        
        smape_dtr = cross_val_score(dtr, features_train, 
                                    np.array(target_train), 
                                    scoring=smape_score, cv=5
                                    ).mean() *-1
        
        if smape_dtr < best_smape_dtr:
            best_smape_dtr = smape_dtr
            best_model_dtr = dtr
         
        
print(best_model_dtr)
print(best_smape_dtr)
# Out:
# DecisionTreeRegressor(max_depth=2, max_features=12,
#                       random_state=RandomState(MT19937) at 0x26C102B5740)
# 8.823172432634454
# CPU times: total: 1min 15s
# Wall time: 1min 16s

# %% [markdown]
# **Линейная регрессия**

# %%
lr = LinearRegression()

smape_lr = cross_val_score(lr, features_train, 
                           np.array(target_train), 
                           scoring=smape_score, cv=5
                           ).mean() *-1

print('Оценка качества модели Линейной регрессии по метрике sMAPE  :', smape_lr)
# Out:
# Оценка качества модели Линейной регрессии по метрике sMAPE  : 9.968149769065727

# %% [markdown]
#                 Наименьшее значение симметричного среднего абсолютного процентного отклонения sMAPE
#                                     показала модель Случайного леса с параметрами:
#
#                      RandomForestRegressor(max_depth=3, n_estimators=2, random_state=STATE)

# %% [markdown]
# **Проверка лучшей модели на тестовой выборке**

# %%
test_rf = RandomForestRegressor(max_depth=3, 
                                n_estimators=2, 
                                random_state=STATE)

test_rf.fit(features_train, np.array(target_train))
test_predicted = test_rf.predict(features_test)

test_smape = smape(np.array(target_test), test_predicted)

print('sMAPE лучшей модели на тестовой выборке:', test_smape)
# Out:
# sMAPE лучшей модели на тестовой выборке: 9.267908082216598

# %% [markdown]
# ## **РЕЗУЛЬТАТЫ**

# %% [markdown]
# В результате анализа исходных данных и работы на задачей, установили следующее:
#
#
# - в данных исходных данных пропуски, данные имеют большой разброс, отрицательные значения, например, в столбцах secondary_cleaner.state.floatbank#, дата и время получения информации (признак date) имеет тип данных object,
#
#
# - данные индексируются датой и временем получения информации (признак date) с шагом в 1 час, остальные признаки, характеризующие технологический процесс имеют тип данных float64,
#
#
# - обучающая выборка составляет ~ 73% исходных данных, тестовая выборка ~ 27% исходных данных,
#
#
# - тестовая выборка содержит меньшее количество признаков, чем обучающая, исходный датасет имеет 19439 наблюдений, 87 признаков.
#
#
#
# - Проверена корректность расчета эффективности обогащения:  эффективность обогащения рассчитана правильно, так как значение MAE между расчётами на обучающей выборке и значением признака rougher.output.recovery в данных крайне мало.
#
#
# - В тестовой выборке отсутствовало 39% параметров обучающей выборки, а именно, все выходные параметры : output; и расчеты : calculation, а главное - целевые признаки rougher.output.recovery и final.output.recovery, которые нужны для расчета метрики качества sMAPE.
#
#
# - В тестовую выборку из исходного набора данных были добавлены целевые признаки. Из обучающей выборки были удалены признаки, которых не было в тестовой.
#
#
# - Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки:
#
#
# ЗОЛОТО:
# Концентрация золота увеличивается, проходя все стадии очистки. Финальная концентрация примерно в 5,6 раза больше концентрации в сырье.
#
#
# СЕРЕБРО:
# Концентрация серебра достигает максимального среднего/медианного значения на этапе флотации, и далее начинает снижаться до уровня, ниже концентрации в первичном сырье.
#
#
# СВИНЕЦ:
# Концентрация свинца растет до уровня после первичной очистки, и далее увеличивается незначительно.
#
#
# - Статистические параметры распределений размеров гранул сырья на обучающей и тестовой выборках различаются незначительно.
#
#
# - Средняя/медианная суммарная концентрация всех веществ в сырье примерно на 19% меньше, чем на этапе чернового и финального концентрата.
#
#
# - Наименьшее значение симметричного среднего абсолютного процентного отклонения sMAPE показала модель Случайного леса с параметрами : max_depth=3, n_estimators=2, random_state=STATE.
#
#
# - sMape лучшей модели на тестовой выборке несколько хуже, чем на обучающей, однако лучше константной модели.
